# %%
from tkinter import *
from tkinter import ttk
import pymysql
from tkinter import messagebox 

window = Tk()
window.title("Registration Form")
window.geometry('900x800')
window.configure();
#window.resizable(False,False)


ra110 = pymysql.connect(host="localhost",user="root",password="",database="input1")
c = ra110.cursor()
def submit110():
    
    messagebox.askquestion("Registration Form", "Do you want to Submit")
    ra110 = pymysql.connect(host="localhost",user="root",password="",database="input1")
    c = ra110.cursor()
    c.execute("SELECT * FROM data ")
    r=c.fetchall()
    print(r)
    c.execute("INSERT INTO data  (seat_cap110,plate_num110,other110,letters110,owner_name110,tel_num110,cus_num110,address110,city110,state110,zipcode110,email_address110,co_owner_name110,co_tel_num110,co_cus_num110,co_address110,co_city110,co_state110,co_zipcode110,co_email_address110,add_town110,add_new_date110,add_address110,add_city110,add_state110,add_zipcode110) VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",
             (
                 seat_cap110.get(), 
                 plate_num110.get(), 
                 other110.get(),
                 letters110.get(),
                 owner_name110.get(),
                 tel_num110.get(),
                 cus_num110.get(),
                 address110.get(),
                 city110.get(),
                 state110.get(),
                 zipcode110.get(),
                 email_address110.get(),
                 co_owner_name110.get(),
                 co_tel_num110.get(),
                 co_cus_num110.get(),
                 co_address110.get(),
                 co_city110.get(),
                 co_state110.get(),
                 co_zipcode110.get(),
                 co_email_address110.get(),
                 add_town110.get(),
                 add_new_date110.get(),
                 add_address110.get(),
                 
                 add_state110.get(),
                 add_zipcode110.get()
             ))
    messagebox.showinfo("Registration Form","Submitted Succesfully")       
                 
    ra110.commit() 
    ra110.close()
                 
    r1.deselect()
    r2.deselect()
    r3.deselect()
    r111.deselect()
    r222.deselect()
    c1.deselect()
    c2.deselect()
    c3.deselect()
    r11.deselect()
    r22.deselect()
    r33.deselect()
    r44.deselect()
    r55.deselect()
    r55.deselect()
    r66.deselect()
    r77.deselect()
    r88.deselect()
    r99.deselect()
    r100.deselect()
    r111.deselect()
    seat_cap110.delete(0, END)
    plate_num110.delete(0, END)
    letters110.delete(0, END)
    other110.delete(0, END)
    owner_name110.delete(0, END)
    tel_num110.delete(0, END)
    cus_num110.delete(0, END)
    address110.delete(0, END)
    city110.delete(0, END)
    state110.delete(0, END)
    zipcode110.delete(0, END)
    email_address110.delete(0, END)
    co_owner_name110.delete(0, END)
    co_tel_num110.delete(0, END)
    co_cus_num110.delete(0, END)
    co_address110.delete(0, END)
    co_city110.delete(0, END)
    co_state110.delete(0, END)
    co_zipcode110.delete(0, END)
    co_email_address110.delete(0, END)
    add_town110.delete(0, END)
    add_new_date110.delete(0, END)
    add_address110.delete(0, END)
    add_city110.delete(0, END)
    add_state110.delete(0, END)
    add_zipcode110.delete(0, END)
    

    
    

   
    
a = Frame(window, height=40, width=640,bg='pink', relief=SOLID)
a.pack(fill=X)
a = Label(window ,text = "REGISTRATION INFORMATION",fg='black',bg='pink',font=("Times",20,"bold"))
a.place(x=250,y=1)

a = Label(window ,text = "Registration Period",fg='black',font=("Times",12,"bold"))
a.place(x=10,y=50)
v0=IntVar()
v0.set(1)
r1 = Radiobutton(window, text="One Year",variable=v0,value=1)
r2 = Radiobutton(window, text="Two Year ($2 discount applies)",variable=v0,value=2)
r3 = Radiobutton(window, text="Three Year ($3 discount applies)",variable=v0,value=3)
r1.place(x=250,y=50)
r2.place(x=350,y=50)
r3.place(x=560,y=50)

a = Label(window ,text = "Registration Type",fg='black',font=("Times",12,"bold"))
a.place(x=10,y=80)


v0=IntVar()
v0.set(2)
r11 = Radiobutton(window, text="Original",variable=v0,value=1)
r22 = Radiobutton(window, text="Renewable",variable=v0,value=2)
r33 = Radiobutton(window, text="Private",variable=v0,value=3)
r44 = Radiobutton(window, text="Reissue (Plates and Decals) (See Reissue Plates Below Under Plate Information)",variable=v0,value=4)
r55 = Radiobutton(window, text="Reissue (Decals only)",variable=v0,value=5)
r66 = Radiobutton(window, text="Rental vehicle",variable=v0,value=6)
r77 = Radiobutton(window, text="Transfer License Plate Number - ENTER PLATE NUM",variable=v0,value=7)
r88 = Radiobutton(window, text="For Hire (Complete 'For Higher Information' section )",variable=v0,value=8)
r99 = Radiobutton(window, text="Ridesharing (Vanpool) - Seating Capacity",variable=v0,value=9)
r100 = Radiobutton(window, text="Amateur Radio Operator Call Letters - Specify Letters",variable=v0,value=10)
r111 = Radiobutton(window, text="Other - SPECIFY",variable=v0,value=11)
r11.place(x=250,y=80)
r22.place(x=250,y=100)
r33.place(x=250,y=120)
r44.place(x=250,y=140)
r55.place(x=250,y=160)
r66.place(x=250,y=180)
r77.place(x=250,y=200)
r88.place(x=250,y=220)
r99.place(x=250,y=240)
r100.place(x=250,y=260)
r111.place(x=250,y=280)

plate_num110 = Entry(width=7)
plate_num110.place(x=550,y=200)
seat_cap110 = Entry(width=5)
seat_cap110.place(x=500,y=240)
letters110 = Entry(width=10)
letters110.place(x=560,y=260)
other110 = Entry()
other110.place(x=380,y=280)


b = Frame(window, height=38, width=900, bg='pink', relief=SOLID)
b.place(y=310)
b = Label(window ,text = "OWNER INFORMATION",fg='black',bg='pink',font=("Times",20,"bold"))
b.place(x=300,y=310)

b = Label(window ,text = "OWNERS FULL LEGAL NAME",fg='black')
b.place(x=10,y=350)
b = Label(window ,text = "TELEPHONE NUMBER",fg='black')
b.place(x=320,y=350)
b = Label(window ,text = "DMV CUSTOMER NUMBER",fg='black')
b.place(x=515,y=350)
owner_name110 = Entry()
owner_name110.place(x=190, y=350)
tel_num110 = Entry(width=10)
tel_num110.place(x=445, y=350)
cus_num110=Entry()
cus_num110.place(x=665, y=350)
b = Label(window ,text = "CO-OWNERS FULL LEGAL NAME",fg='black')
b.place(x=10,y=380)
b = Label(window ,text = "TELEPHONE NUMBER",fg='black')
b.place(x=320,y=380)
b = Label(window ,text = "DMV CUSTOMER NUMBER",fg='black')
b.place(x=515,y=380)
co_owner_name110 = Entry()
co_owner_name110.place(x=190, y=380)
co_tel_num110 = Entry(width=10)
co_tel_num110.place(x=445, y=380)
co_cus_num110=Entry()
co_cus_num110.place(x=665, y=380)
b = Label(window ,text = "NOTE: Owners MUST provide their residence/business/home address, this address can not be a P.O Box",fg='black',font=("Times",15,"bold"))
b.place(x=10,y=410)
b = Label(window ,text = "OWNERS RESIDENCE/BUSINESS/HOME ADDRESS")
b.place(x=10,y=440)
b = Label(window ,text = "CITY")
b.place(x=430,y=440)
b = Label(window ,text = "STATE")
b.place(x=595,y=440)
b = Label(window ,text = "ZIPCODE")
b.place(x=725,y=440)
address110 = Entry()
address110.place(x=300,y=440)
city110=Entry()
city110.place(x=465,y=440)
state110=Entry(width=12)
state110.place(x=640,y=440)
zipcode110 = Entry(width=9)
zipcode110.place(x=785,y=440)
b = Label(window ,text = "CO-OWNERS RESIDENCE/BUSINESS/HOME ADDRESS")
b.place(x=10,y=470)
b = Label(window ,text = "CITY")
b.place(x=430,y=470)
b = Label(window ,text = "STATE")
b.place(x=595,y=470)
b = Label(window ,text = "ZIPCODE")
b.place(x=725,y=470)
co_address110 = Entry()
co_address110.place(x=300,y=470)
co_city110 = Entry()
co_city110.place(x=465,y=470)
co_state110 = Entry(width=12)
co_state110.place(x=640,y=470)
co_zipcode110 = Entry(width=9)
co_zipcode110.place(x=785,y=470)
b = Label(window ,text = "OWNER E-MAIL ADDRESS")
b.place(x=10,y=500)
b = Label(window ,text = "CO-OWNER E-MAIL ADDRESS")
b.place(x=430,y=500)
email_address110 = Entry()
email_address110.place(x=300,y=500)
co_email_address110 = Entry()
co_email_address110.place(x=640,y=500)

c = Frame(window, height=38, width=900, bg='pink', relief=SOLID)
c.place(y=540)
c = Label(window ,text = "ADDITIONAL INFORMATION",fg='black',bg='pink',font=("Times",20,"bold"))
c.place(x=270,y=540)

c = Label(window ,text = "LOCATION WHERE VEHICLES PRINCIPALLY GRADED")
c.place(x=10,y=580)
city=IntVar()
county=IntVar()
town=IntVar()
c1=Checkbutton(window,text="CITY", variable= city, onvalue=1 )
c1.place(x=310,y=580)
c2=Checkbutton(window,text="COUNTY", variable= county, onvalue=2 )
c2.place(x=400,y=580)
c3=Checkbutton(window,text="TOWN OF", variable= town, onvalue=3 )
c3.place(x=500,y=580)
add_town110 = Entry()
add_town110.place(x=580,y=580)
c = Label(window ,text = "IF NEW LOCATION ENTER DATE CHANGED")
c.place(x=10,y=610)
add_new_date110 = Entry()
add_new_date110.place(x=315,y=610)
c = Label(window ,text = "ACTIVE MILITARY SERVICE")
c.place(x=505,y=610)
v0=IntVar()
v0.set(2)
r111=Radiobutton(window, text="YES",variable=v0,value=1)
r222=Radiobutton(window, text="NO",variable=v0,value=2)
r111.place(x=650,y=610)
r222.place(x=700,y=610)
c = Label(window ,text = "IF YOU WOULD LIKE YOUR REGISTRATION RENEWALS SENT TO AN ADDRESS OTHER THAN RESIDENCE/BUSINESS ADDRESS.ENTER IT BELOW ",fg='black',font=("Times",10,"bold"))
c.place(x=10,y=640)
c = Label(window ,text = "REGISTRATION MAILING ADDRESS")
c.place(x=10,y=670)
c = Label(window ,text = "CITY")
c.place(x=430,y=670)
c = Label(window ,text = "STATE")
c.place(x=595,y=670)
c = Label(window ,text = "ZIPCODE")
c.place(x=725,y=670)
add_address110 = Entry()
add_address110.place(x=300,y=670)
add_city110 = Entry()
add_city110.place(x=465,y=670)
add_state110 = Entry(width=12)
add_state110.place(x=640,y=670)
add_zipcode110 = Entry(width=9)
add_zipcode110.place(x=785,y=670)


submit_btn = ttk.Button(window, text="Submit", command=submit110)
submit_btn.place(x=400,y=700)



ra110.commit() 
ra110.close()

window.mainloop()
# Out:
# ()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sanka\anaconda3\lib\tkinter\__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-3-511e70ba5fa0>", line 23, in submit110
#     c.execute("INSERT INTO data  (seat_cap110,plate_num110,other110,letters110,owner_name110,tel_num110,cus_num110,address110,city110,state110,zipcode110,email_address110,co_owner_name110,co_tel_num110,co_cus_num110,co_address110,co_city110,co_state110,co_zipcode110,co_email_address110,add_town110,add_new_date110,add_address110,add_city110,add_state110,add_zipcode110) VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",
#   File "C:\Users\sanka\anaconda3\lib\site-packages\pymysql\cursors.py", line 146, in execute
#     query = self.mogrify(query, args)
#   File "C:\Users\sanka\anaconda3\lib\site-packages\pymysql\cursors.py", line 125, in mogrify
#     query = query % self._escape_args(args, conn)
# TypeError: not enough arguments for format string
